# %%
# !ls /kaggle/input
import os
print(os.listdir("/kaggle/input/evaluation/eval"))
import sys
# replace <slug> with your dataset’s folder name
script_path = "/kaggle/input/evaluation/eval"
sys.path.insert(0, script_path)
# Out:
# adain-output  content-style  evaluation  nst-infer  stylized
# ['evaluation.ipynb', 'data', 'evaluation']

# %%
# !pip install lpips
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.3 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.2 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 3.3 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 5.2 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.2 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 71.9 MB/s eta 0:00:00:00:0100:01
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.9.41
#     Uninstalling nvidia-nvjitlink-cu12-12.9.41:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.9.41
# ...

# %%
# !pip install pytorch_msssim

# %%
from evaluation.eval_artfid import evaluate
import torch

# %%
device = 'cuda'

# %% [markdown]
# PATCH_ST

# %%
content_path = "/kaggle/input/evaluation/eval/data/contents"
style_path = "/kaggle/input/evaluation/eval/data/styles"
stylised_path = "/kaggle/input/nst-infer/output"
artfid, fid, lp, lp_g, cfsd = evaluate(content_path, style_path, stylised_path, device = device)
# Out:
# Downloading: "https://huggingface.co/matthias-wright/art_inception/resolve/main/art_inception.pt" to /tmp/art_fid/art_inception.pth
# 100%|██████████| 108M/108M [00:01<00:00, 107MiB/s]
# ...
# Activations:   2%|▏         | 1/50 [00:14<11:27, 14.03s/it]
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...

# %% [markdown]
# WCT

# %%
content_path = "/kaggle/input/evaluation/eval/data/contents"
style_path = "/kaggle/input/evaluation/eval/data/styles"
stylised_path = "/kaggle/input/stylized/outputs"
artfid, fid, lp, lp_g, cfsd = evaluate(content_path, style_path, stylised_path, device = device)
# Out:
# ...
# Activations:   2%|▏         | 1/50 [00:13<11:19, 13.87s/it]
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: /usr/local/lib/python3.11/dist-packages/lpips/weights/v0.1/alex.pth
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: /usr/local/lib/python3.11/dist-packages/lpips/weights/v0.1/alex.pth
# ArtFID: 39.6677   FID: 24.5257   lpips: 0.5540   Gray: 0.5830
# CFSD: 0.3421

# %% [markdown]
# TRANSFORMER

# %%
content_path = "/kaggle/input/evaluation/eval/data/contents"
style_path = "/kaggle/input/evaluation/eval/data/styles"
stylised_path = "/kaggle/input/content-style/content_style_image"
artfid, fid, lp, lp_g, cfsd = evaluate(content_path, style_path, stylised_path, device = device)
# Out:
# ...
# Activations:   2%|▏         | 1/50 [00:01<01:14,  1.52s/it]
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: /usr/local/lib/python3.11/dist-packages/lpips/weights/v0.1/alex.pth
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: /usr/local/lib/python3.11/dist-packages/lpips/weights/v0.1/alex.pth
# ArtFID: 49.5237   FID: 28.7608   lpips: 0.6641   Gray: 0.5344
# CFSD: 1.0219

# %% [markdown]
# ADAIN

# %%
content_path = "/kaggle/input/evaluation/eval/data/contents"
style_path = "/kaggle/input/evaluation/eval/data/styles"
stylised_path = "/kaggle/input/adain-output/adain"
artfid, fid, lp, lp_g, cfsd = evaluate(content_path, style_path, stylised_path, device = device)
# Out:
# ...
# Activations:   2%|▏         | 1/50 [00:01<01:24,  1.72s/it]
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: /usr/local/lib/python3.11/dist-packages/lpips/weights/v0.1/alex.pth
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: /usr/local/lib/python3.11/dist-packages/lpips/weights/v0.1/alex.pth
# ArtFID: 40.1263   FID: 26.1064   lpips: 0.4803   Gray: 0.5076
# CFSD: 0.2297
